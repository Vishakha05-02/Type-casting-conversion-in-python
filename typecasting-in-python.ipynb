# %%
#float to int
x = int(12.44)
print(x)
type(x)

# %%
#int to float
x = 10
i = float(x)
print(i)
type(i)

# %%
#int to float
x = 1234
print(float(x))

# %%
boolean to str
a = str(True)
type(a)

# %%
#str to int
y = int('12345')
print(y)
type(y)

# %%
#str to float
x = float('123')
print(x)
type(x)

# %%
#int to str
z = str(12345)
type(z)

# %%
#int to complex
c = complex(1,2) 
print(c)
type(c)

# %%
x = str(2+4j)
print(x)
type(x)

# %%
#tuple()
#set()
#list()

# %%
s = 'PYTHON'
  
# printing string converting to tuple 
c = tuple(s) 
print ("After converting string to tuple : ",end="") 
print(c)

# %%
# printing string converting to set 
s = 'PYTHON'
c = set(s) 
print ("After converting string to set : ",end="") 
print (c)

# %%
# printing string converting to list 
s = 'PYTHON'
c = list(s) 
print ("After converting string to list : ",end="") 
print (c)

# %%
#printing tuple converting to dict
tup = ((1,2), (3,4), (5,6))
my_dict = dict(tup)
print(my_dict)
